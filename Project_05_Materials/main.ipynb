# %% [markdown]
# # SQL

# %%
import sqlite3 as sq3
import pandas as pd
import json

# %%
# importing json file
with open('some_movies.json') as f:
    data = json.load(f)
    
# creating a datafram
df = pd.json_normalize(data,sep = "_")

movies = df[['id','title','revenue','budget','belongs_to_collection_name','release_date']].copy()
movies['release_date'] = pd.to_datetime(df['release_date'])
movies['revenue'] = df['revenue']/1000000
movies['budget'] = df['budget']/1000000

#creating a second dataframe
votes = df[['id','vote_count','vote_average']].copy()

# %%
# convert genre column in a separate dataframe
genres = pd.json_normalize(data = data,
                          record_path = 'genres',
                          #meta='id',
                          record_prefix = 'genre_')

# %%
genres = pd.json_normalize(data = data,
                          record_path = 'genres',
                          record_prefix = 'genre_',
                          meta='id')
genres.head(2)
# Out:
#    genre_id       genre_name      id
# 0        12        Adventure  299534
# 1       878  Science Fiction  299534

# %%
prod = pd.json_normalize(data=data,
                         record_path = 'production_companies',
                         record_prefix = 'comp_',
                         meta = 'id')

# %%
con = sq3.connect('movies.db')

# %%
movies.to_sql('Movies',# nome da tabela
              con,
              index=False)

votes.to_sql('Votes',con,index=False)

genres.to_sql('Genres',con,index=False)

prod.to_sql('Prod',con,index=False)

# %%
con.execute('Select * FROM sqlite_master').fetchall()
# Out:
# [('table',
#   'Movies',
#   'Movies',
#   2,
#   'CREATE TABLE "Movies" (\n"id" INTEGER,\n  "title" TEXT,\n  "revenue" REAL,\n  "budget" REAL,\n  "belongs_to_collection_name" TEXT,\n  "release_date" TIMESTAMP\n)'),
#  ('table',
#   'Votes',
#   'Votes',
#   3,
#   'CREATE TABLE "Votes" (\n"id" INTEGER,\n  "vote_count" INTEGER,\n  "vote_average" REAL\n)'),
#  ('table',
#   'Genres',
#   'Genres',
#   4,
#   'CREATE TABLE "Genres" (\n"genre_id" INTEGER,\n  "genre_name" TEXT,\n  "id" INTEGER\n)'),
#  ('table',
#   'Prod',
#   'Prod',
#   5,
#   'CREATE TABLE "Prod" (\n"comp_id" INTEGER,\n  "comp_logo_path" TEXT,\n  "comp_name" TEXT,\n  "comp_origin_country" TEXT,\n  "id" INTEGER\n)')]

# %%
con.execute("SELECT name FROM sqlite_master WHERE type='table' ORDER BY name").fetchall()
# Out:
# [('Genres',), ('Movies',), ('Prod',), ('Votes',)]

# %%
con.close()

# %% [markdown]
# # Loading Data from SQLite Databases into DataFrames

# %%
import pandas as pd
import sqlite3 as sq3

# %%
con = sq3.connect("movies.db")

# %%
con.execute("Select * FROM sqlite_master").fetchall()
# Out:
# [('table',
#   'Movies',
#   'Movies',
#   2,
#   'CREATE TABLE "Movies" (\n"id" INTEGER,\n  "title" TEXT,\n  "revenue" REAL,\n  "budget" REAL,\n  "belongs_to_collection_name" TEXT,\n  "release_date" TIMESTAMP\n)'),
#  ('table',
#   'Votes',
#   'Votes',
#   3,
#   'CREATE TABLE "Votes" (\n"id" INTEGER,\n  "vote_count" INTEGER,\n  "vote_average" REAL\n)'),
#  ('table',
#   'Genres',
#   'Genres',
#   4,
#   'CREATE TABLE "Genres" (\n"genre_id" INTEGER,\n  "genre_name" TEXT,\n  "id" INTEGER\n)'),
#  ('table',
#   'Prod',
#   'Prod',
#   5,
#   'CREATE TABLE "Prod" (\n"comp_id" INTEGER,\n  "comp_logo_path" TEXT,\n  "comp_name" TEXT,\n  "comp_origin_country" TEXT,\n  "id" INTEGER\n)')]

# %%
df = pd.read_sql("SELECT * FROM Movies",con,
                 index_col = "id",
                 parse_dates = "release_date")
df
# Out:
#                                                title      revenue  budget  \
# id
# 299534                             Avengers: Endgame  2797.800564   356.0
# 19995                                         Avatar  2787.965087   237.0
# 140607                  Star Wars: The Force Awakens  2068.223624   245.0
# 299536                        Avengers: Infinity War  2046.239637   300.0
# 597                                          Titanic  1845.034188   200.0
# 135397                                Jurassic World  1671.713208   150.0
# 420818                                 The Lion King  1656.943394   260.0
# 24428                                   The Avengers  1519.557910   220.0
# 168259                                     Furious 7  1515.047671   190.0
# 99861                        Avengers: Age of Ultron  1405.403694   250.0
# 284054                                 Black Panther  1346.739107   200.0
# 12445   Harry Potter and the Deathly Hallows: Part 2  1341.511219   125.0
# 181808                      Star Wars: The Last Jedi  1332.539889   200.0
# 330457                                     Frozen II  1330.764959   150.0
# 351286                Jurassic World: Fallen Kingdom  1303.459585   170.0
# 109445                                        Frozen  1274.219009   150.0
# 321612                          Beauty and the Beast  1263.521126   160.0
# 260513                                 Incredibles 2  1241.891456   200.0
#
#                  belongs_to_collection_name release_date
# id
# 299534              The Avengers Collection   2019-04-24
# 19995                     Avatar Collection   2009-12-10
# 140607                 Star Wars Collection   2015-12-15
# 299536              The Avengers Collection   2018-04-25
# 597                                    None   1997-11-18
# 135397             Jurassic Park Collection   2015-06-06
# 420818                                 None   2019-07-12
# 24428               The Avengers Collection   2012-04-25
# 168259  The Fast and the Furious Collection   2015-04-01
# 99861               The Avengers Collection   2015-04-22
# 284054             Black Panther Collection   2018-02-13
# 12445               Harry Potter Collection   2011-07-07
# 181808                 Star Wars Collection   2017-12-13
# 330457                    Frozen Collection   2019-11-20
# 351286             Jurassic Park Collection   2018-06-06
# 109445                    Frozen Collection   2013-11-27
# 321612                                 None   2017-03-16
# 260513           The Incredibles Collection   2018-06-14

# %%
genres = pd.read_sql("SELECT * FROM Genres",
                     con,
                     index_col = "id"
                    )

# %%
con.close()

# %% [markdown]
# # Some Simple SQL Queries

# %%
import pandas as pd
import sqlite3 as sq3

# %% [raw]
# Connecting

# %%
con = sq3.connect("movies.db")

# %% [raw]
# Reading the Movies Tables

# %%
pd.read_sql("SELECT * FROM Movies",con)
# Out:
#         id                                         title      revenue  budget  \
# 0   299534                             Avengers: Endgame  2797.800564   356.0
# 1    19995                                        Avatar  2787.965087   237.0
# 2   140607                  Star Wars: The Force Awakens  2068.223624   245.0
# 3   299536                        Avengers: Infinity War  2046.239637   300.0
# 4      597                                       Titanic  1845.034188   200.0
# 5   135397                                Jurassic World  1671.713208   150.0
# 6   420818                                 The Lion King  1656.943394   260.0
# 7    24428                                  The Avengers  1519.557910   220.0
# 8   168259                                     Furious 7  1515.047671   190.0
# 9    99861                       Avengers: Age of Ultron  1405.403694   250.0
# 10  284054                                 Black Panther  1346.739107   200.0
# 11   12445  Harry Potter and the Deathly Hallows: Part 2  1341.511219   125.0
# 12  181808                      Star Wars: The Last Jedi  1332.539889   200.0
# 13  330457                                     Frozen II  1330.764959   150.0
# 14  351286                Jurassic World: Fallen Kingdom  1303.459585   170.0
# 15  109445                                        Frozen  1274.219009   150.0
# 16  321612                          Beauty and the Beast  1263.521126   160.0
# 17  260513                                 Incredibles 2  1241.891456   200.0
#
#              belongs_to_collection_name         release_date
# 0               The Avengers Collection  2019-04-24 00:00:00
# 1                     Avatar Collection  2009-12-10 00:00:00
# 2                  Star Wars Collection  2015-12-15 00:00:00
# 3               The Avengers Collection  2018-04-25 00:00:00
# 4                                  None  1997-11-18 00:00:00
# 5              Jurassic Park Collection  2015-06-06 00:00:00
# 6                                  None  2019-07-12 00:00:00
# 7               The Avengers Collection  2012-04-25 00:00:00
# 8   The Fast and the Furious Collection  2015-04-01 00:00:00
# 9               The Avengers Collection  2015-04-22 00:00:00
# 10             Black Panther Collection  2018-02-13 00:00:00
# 11              Harry Potter Collection  2011-07-07 00:00:00
# 12                 Star Wars Collection  2017-12-13 00:00:00
# 13                    Frozen Collection  2019-11-20 00:00:00
# 14             Jurassic Park Collection  2018-06-06 00:00:00
# 15                    Frozen Collection  2013-11-27 00:00:00
# 16                                 None  2017-03-16 00:00:00
# 17           The Incredibles Collection  2018-06-14 00:00:00

# %% [raw]
# The backslash is to writte in another line

# %%
pd.read_sql("SELECT * \
             FROM Movies",con)
# Out:
#         id                                         title      revenue  budget  \
# 0   299534                             Avengers: Endgame  2797.800564   356.0
# 1    19995                                        Avatar  2787.965087   237.0
# 2   140607                  Star Wars: The Force Awakens  2068.223624   245.0
# 3   299536                        Avengers: Infinity War  2046.239637   300.0
# 4      597                                       Titanic  1845.034188   200.0
# 5   135397                                Jurassic World  1671.713208   150.0
# 6   420818                                 The Lion King  1656.943394   260.0
# 7    24428                                  The Avengers  1519.557910   220.0
# 8   168259                                     Furious 7  1515.047671   190.0
# 9    99861                       Avengers: Age of Ultron  1405.403694   250.0
# 10  284054                                 Black Panther  1346.739107   200.0
# 11   12445  Harry Potter and the Deathly Hallows: Part 2  1341.511219   125.0
# 12  181808                      Star Wars: The Last Jedi  1332.539889   200.0
# 13  330457                                     Frozen II  1330.764959   150.0
# 14  351286                Jurassic World: Fallen Kingdom  1303.459585   170.0
# 15  109445                                        Frozen  1274.219009   150.0
# 16  321612                          Beauty and the Beast  1263.521126   160.0
# 17  260513                                 Incredibles 2  1241.891456   200.0
#
#              belongs_to_collection_name         release_date
# 0               The Avengers Collection  2019-04-24 00:00:00
# 1                     Avatar Collection  2009-12-10 00:00:00
# 2                  Star Wars Collection  2015-12-15 00:00:00
# 3               The Avengers Collection  2018-04-25 00:00:00
# 4                                  None  1997-11-18 00:00:00
# 5              Jurassic Park Collection  2015-06-06 00:00:00
# 6                                  None  2019-07-12 00:00:00
# 7               The Avengers Collection  2012-04-25 00:00:00
# 8   The Fast and the Furious Collection  2015-04-01 00:00:00
# 9               The Avengers Collection  2015-04-22 00:00:00
# 10             Black Panther Collection  2018-02-13 00:00:00
# 11              Harry Potter Collection  2011-07-07 00:00:00
# 12                 Star Wars Collection  2017-12-13 00:00:00
# 13                    Frozen Collection  2019-11-20 00:00:00
# 14             Jurassic Park Collection  2018-06-06 00:00:00
# 15                    Frozen Collection  2013-11-27 00:00:00
# 16                                 None  2017-03-16 00:00:00
# 17           The Incredibles Collection  2018-06-14 00:00:00

# %% [raw]
# Selecting specific columns

# %%
pd.read_sql("SELECT id, revenue,release_date FROM Movies",con)
# Out:
#         id      revenue         release_date
# 0   299534  2797.800564  2019-04-24 00:00:00
# 1    19995  2787.965087  2009-12-10 00:00:00
# 2   140607  2068.223624  2015-12-15 00:00:00
# 3   299536  2046.239637  2018-04-25 00:00:00
# 4      597  1845.034188  1997-11-18 00:00:00
# 5   135397  1671.713208  2015-06-06 00:00:00
# 6   420818  1656.943394  2019-07-12 00:00:00
# 7    24428  1519.557910  2012-04-25 00:00:00
# 8   168259  1515.047671  2015-04-01 00:00:00
# 9    99861  1405.403694  2015-04-22 00:00:00
# 10  284054  1346.739107  2018-02-13 00:00:00
# 11   12445  1341.511219  2011-07-07 00:00:00
# 12  181808  1332.539889  2017-12-13 00:00:00
# 13  330457  1330.764959  2019-11-20 00:00:00
# 14  351286  1303.459585  2018-06-06 00:00:00
# 15  109445  1274.219009  2013-11-27 00:00:00
# 16  321612  1263.521126  2017-03-16 00:00:00
# 17  260513  1241.891456  2018-06-14 00:00:00

# %% [raw]
# Operating over columns with pandas

# %%
pd.read_sql("SELECT sum(revenue) FROM Movies",con)
# Out:
#    sum(revenue)
# 0  29748.575327

# %%
pd.read_sql("SELECT count(title) FROM Movies",con)
# Out:
#    count(title)
# 0            18

# %%
# this method dont count repetitions
pd.read_sql("SELECT count(belongs_to_collection_name) FROM Movies",con)
# Out:
#    count(belongs_to_collection_name)
# 0                                 15

# %%
pd.read_sql("SELECT count(*) FROM Movies",con)
# Out:
#    count(*)
# 0        18

# %%
pd.read_sql("SELECT avg(budget) FROM Movies",con)
# Out:
#    avg(budget)
# 0   209.055556

# %% [raw]
# Operating over columns with sqlite

# %%
con.execute("SELECT sum(revenue) FROM Movies").fetchall()[0][0]
# Out:
# 29748.575327000002

# %%
pd.read_sql("SELECT * FROM Movies WHERE id = 597",con)
# Out:
#     id    title      revenue  budget belongs_to_collection_name  \
# 0  597  Titanic  1845.034188   200.0                       None
#
#           release_date
# 0  1997-11-18 00:00:00

# %%
pd.read_sql("SELECT * FROM Movies WHERE revenue > 2000",con)
# Out:
#        id                         title      revenue  budget  \
# 0  299534             Avengers: Endgame  2797.800564   356.0
# 1   19995                        Avatar  2787.965087   237.0
# 2  140607  Star Wars: The Force Awakens  2068.223624   245.0
# 3  299536        Avengers: Infinity War  2046.239637   300.0
#
#   belongs_to_collection_name         release_date
# 0    The Avengers Collection  2019-04-24 00:00:00
# 1          Avatar Collection  2009-12-10 00:00:00
# 2       Star Wars Collection  2015-12-15 00:00:00
# 3    The Avengers Collection  2018-04-25 00:00:00

# %%
pd.read_sql("SELECT * FROM Movies WHERE \
             revenue > 1500 AND budget < 200 ",con)
# Out:
#        id           title      revenue  budget  \
# 0  135397  Jurassic World  1671.713208   150.0
# 1  168259       Furious 7  1515.047671   190.0
#
#             belongs_to_collection_name         release_date
# 0             Jurassic Park Collection  2015-06-06 00:00:00
# 1  The Fast and the Furious Collection  2015-04-01 00:00:00

# %%
pd.read_sql("SELECT * FROM Movies WHERE \
             revenue > 1500 AND budget < 200 ",con)

# %%
pd.read_sql("SELECT MIN(budget) FROM Movies \
             WHERE revenue > 1250",con)
# Out:
#    MIN(budget)
# 0        125.0

# %%
pd.read_sql("SELECT DISTINCT title FROM Movies",con)
# Out:
#                                            title
# 0                              Avengers: Endgame
# 1                                         Avatar
# 2                   Star Wars: The Force Awakens
# 3                         Avengers: Infinity War
# 4                                        Titanic
# 5                                 Jurassic World
# 6                                  The Lion King
# 7                                   The Avengers
# 8                                      Furious 7
# 9                        Avengers: Age of Ultron
# 10                                 Black Panther
# 11  Harry Potter and the Deathly Hallows: Part 2
# 12                      Star Wars: The Last Jedi
# 13                                     Frozen II
# 14                Jurassic World: Fallen Kingdom
# 15                                        Frozen
# 16                          Beauty and the Beast
# 17                                 Incredibles 2

# %%
pd.read_sql("SELECT * FROM Movies ORDER BY budget DESC",con)
# Out:
#         id                                         title      revenue  budget  \
# 0   299534                             Avengers: Endgame  2797.800564   356.0
# 1   299536                        Avengers: Infinity War  2046.239637   300.0
# 2   420818                                 The Lion King  1656.943394   260.0
# 3    99861                       Avengers: Age of Ultron  1405.403694   250.0
# 4   140607                  Star Wars: The Force Awakens  2068.223624   245.0
# 5    19995                                        Avatar  2787.965087   237.0
# 6    24428                                  The Avengers  1519.557910   220.0
# 7      597                                       Titanic  1845.034188   200.0
# 8   284054                                 Black Panther  1346.739107   200.0
# 9   181808                      Star Wars: The Last Jedi  1332.539889   200.0
# 10  260513                                 Incredibles 2  1241.891456   200.0
# 11  168259                                     Furious 7  1515.047671   190.0
# 12  351286                Jurassic World: Fallen Kingdom  1303.459585   170.0
# 13  321612                          Beauty and the Beast  1263.521126   160.0
# 14  135397                                Jurassic World  1671.713208   150.0
# 15  330457                                     Frozen II  1330.764959   150.0
# 16  109445                                        Frozen  1274.219009   150.0
# 17   12445  Harry Potter and the Deathly Hallows: Part 2  1341.511219   125.0
#
#              belongs_to_collection_name         release_date
# 0               The Avengers Collection  2019-04-24 00:00:00
# 1               The Avengers Collection  2018-04-25 00:00:00
# 2                                  None  2019-07-12 00:00:00
# 3               The Avengers Collection  2015-04-22 00:00:00
# 4                  Star Wars Collection  2015-12-15 00:00:00
# 5                     Avatar Collection  2009-12-10 00:00:00
# 6               The Avengers Collection  2012-04-25 00:00:00
# 7                                  None  1997-11-18 00:00:00
# 8              Black Panther Collection  2018-02-13 00:00:00
# 9                  Star Wars Collection  2017-12-13 00:00:00
# 10           The Incredibles Collection  2018-06-14 00:00:00
# 11  The Fast and the Furious Collection  2015-04-01 00:00:00
# 12             Jurassic Park Collection  2018-06-06 00:00:00
# 13                                 None  2017-03-16 00:00:00
# 14             Jurassic Park Collection  2015-06-06 00:00:00
# 15                    Frozen Collection  2019-11-20 00:00:00
# 16                    Frozen Collection  2013-11-27 00:00:00
# 17              Harry Potter Collection  2011-07-07 00:00:00

# %%
pd.read_sql("SELECT * FROM Movies WHERE \
             title LIKE 'Avengers%'",con)
# Out:
#        id                    title      revenue  budget  \
# 0  299534        Avengers: Endgame  2797.800564   356.0
# 1  299536   Avengers: Infinity War  2046.239637   300.0
# 2   99861  Avengers: Age of Ultron  1405.403694   250.0
#
#   belongs_to_collection_name         release_date
# 0    The Avengers Collection  2019-04-24 00:00:00
# 1    The Avengers Collection  2018-04-25 00:00:00
# 2    The Avengers Collection  2015-04-22 00:00:00

# %%
pd.read_sql("SELECT * FROM Movies WHERE \
             belongs_to_collection_name IS NULL",con)
# Out:
#        id                 title      revenue  budget  \
# 0     597               Titanic  1845.034188   200.0
# 1  420818         The Lion King  1656.943394   260.0
# 2  321612  Beauty and the Beast  1263.521126   160.0
#
#   belongs_to_collection_name         release_date
# 0                       None  1997-11-18 00:00:00
# 1                       None  2019-07-12 00:00:00
# 2                       None  2017-03-16 00:00:00

# %%
pd.read_sql("SELECT * FROM Movies WHERE \
             belongs_to_collection_name IS NOT NULL",con)
# Out:
#         id                                         title      revenue  budget  \
# 0   299534                             Avengers: Endgame  2797.800564   356.0
# 1    19995                                        Avatar  2787.965087   237.0
# 2   140607                  Star Wars: The Force Awakens  2068.223624   245.0
# 3   299536                        Avengers: Infinity War  2046.239637   300.0
# 4   135397                                Jurassic World  1671.713208   150.0
# 5    24428                                  The Avengers  1519.557910   220.0
# 6   168259                                     Furious 7  1515.047671   190.0
# 7    99861                       Avengers: Age of Ultron  1405.403694   250.0
# 8   284054                                 Black Panther  1346.739107   200.0
# 9    12445  Harry Potter and the Deathly Hallows: Part 2  1341.511219   125.0
# 10  181808                      Star Wars: The Last Jedi  1332.539889   200.0
# 11  330457                                     Frozen II  1330.764959   150.0
# 12  351286                Jurassic World: Fallen Kingdom  1303.459585   170.0
# 13  109445                                        Frozen  1274.219009   150.0
# 14  260513                                 Incredibles 2  1241.891456   200.0
#
#              belongs_to_collection_name         release_date
# 0               The Avengers Collection  2019-04-24 00:00:00
# 1                     Avatar Collection  2009-12-10 00:00:00
# 2                  Star Wars Collection  2015-12-15 00:00:00
# 3               The Avengers Collection  2018-04-25 00:00:00
# 4              Jurassic Park Collection  2015-06-06 00:00:00
# 5               The Avengers Collection  2012-04-25 00:00:00
# 6   The Fast and the Furious Collection  2015-04-01 00:00:00
# 7               The Avengers Collection  2015-04-22 00:00:00
# 8              Black Panther Collection  2018-02-13 00:00:00
# 9               Harry Potter Collection  2011-07-07 00:00:00
# 10                 Star Wars Collection  2017-12-13 00:00:00
# 11                    Frozen Collection  2019-11-20 00:00:00
# 12             Jurassic Park Collection  2018-06-06 00:00:00
# 13                    Frozen Collection  2013-11-27 00:00:00
# 14           The Incredibles Collection  2018-06-14 00:00:00

# %%
con.close()

# %% [markdown]
# # Join SQL Queries

# %%
import pandas as pd
import sqlite3 as sq3

# %% [raw]
# Connecting

# %%
con = sq3.connect("movies.db")

# %%
pd.read_sql("SELECT * FROM Movies", con)
# Out:
#         id                                         title      revenue  budget  \
# 0   299534                             Avengers: Endgame  2797.800564   356.0
# 1    19995                                        Avatar  2787.965087   237.0
# 2   140607                  Star Wars: The Force Awakens  2068.223624   245.0
# 3   299536                        Avengers: Infinity War  2046.239637   300.0
# 4      597                                       Titanic  1845.034188   200.0
# 5   135397                                Jurassic World  1671.713208   150.0
# 6   420818                                 The Lion King  1656.943394   260.0
# 7    24428                                  The Avengers  1519.557910   220.0
# 8   168259                                     Furious 7  1515.047671   190.0
# 9    99861                       Avengers: Age of Ultron  1405.403694   250.0
# 10  284054                                 Black Panther  1346.739107   200.0
# 11   12445  Harry Potter and the Deathly Hallows: Part 2  1341.511219   125.0
# 12  181808                      Star Wars: The Last Jedi  1332.539889   200.0
# 13  330457                                     Frozen II  1330.764959   150.0
# 14  351286                Jurassic World: Fallen Kingdom  1303.459585   170.0
# 15  109445                                        Frozen  1274.219009   150.0
# 16  321612                          Beauty and the Beast  1263.521126   160.0
# 17  260513                                 Incredibles 2  1241.891456   200.0
#
#              belongs_to_collection_name         release_date
# 0               The Avengers Collection  2019-04-24 00:00:00
# 1                     Avatar Collection  2009-12-10 00:00:00
# 2                  Star Wars Collection  2015-12-15 00:00:00
# 3               The Avengers Collection  2018-04-25 00:00:00
# 4                                  None  1997-11-18 00:00:00
# 5              Jurassic Park Collection  2015-06-06 00:00:00
# 6                                  None  2019-07-12 00:00:00
# 7               The Avengers Collection  2012-04-25 00:00:00
# 8   The Fast and the Furious Collection  2015-04-01 00:00:00
# 9               The Avengers Collection  2015-04-22 00:00:00
# 10             Black Panther Collection  2018-02-13 00:00:00
# 11              Harry Potter Collection  2011-07-07 00:00:00
# 12                 Star Wars Collection  2017-12-13 00:00:00
# 13                    Frozen Collection  2019-11-20 00:00:00
# 14             Jurassic Park Collection  2018-06-06 00:00:00
# 15                    Frozen Collection  2013-11-27 00:00:00
# 16                                 None  2017-03-16 00:00:00
# 17           The Incredibles Collection  2018-06-14 00:00:00

# %%
pd.read_sql("SELECT * FROM Votes", con)
# Out:
#         id  vote_count  vote_average
# 0   299534       12607           8.3
# 1    19995       21000           7.4
# 2   140607       14205           7.4
# 3   299536       17718           8.3
# 4      597       16661           7.8
# 5   135397       15399           6.6
# 6   420818        5425           7.2
# 7    24428       22101           7.7
# 8   168259        7359           7.3
# 9    99861       15548           7.3
# 10  284054       14830           7.4
# 11   12445       13447           8.1
# 12  181808       10304           7.0
# 13  330457        3982           7.2
# 14  351286        7337           6.5
# 15  109445       11616           7.3
# 16  321612       12203           6.9
# 17  260513        8147           7.5

# %%
pd.read_sql("SELECT * \
             FROM Movies \
             JOIN Votes \
             ON Movies.id-Votes.id",con)
# Out:
#          id              title      revenue  budget  \
# 0    299534  Avengers: Endgame  2797.800564   356.0
# 1    299534  Avengers: Endgame  2797.800564   356.0
# 2    299534  Avengers: Endgame  2797.800564   356.0
# 3    299534  Avengers: Endgame  2797.800564   356.0
# 4    299534  Avengers: Endgame  2797.800564   356.0
# ..      ...                ...          ...     ...
# 301  260513      Incredibles 2  1241.891456   200.0
# 302  260513      Incredibles 2  1241.891456   200.0
# 303  260513      Incredibles 2  1241.891456   200.0
# 304  260513      Incredibles 2  1241.891456   200.0
# 305  260513      Incredibles 2  1241.891456   200.0
#
#      belongs_to_collection_name         release_date      id  vote_count  \
# 0       The Avengers Collection  2019-04-24 00:00:00   19995       21000
# 1       The Avengers Collection  2019-04-24 00:00:00  140607       14205
# 2       The Avengers Collection  2019-04-24 00:00:00  299536       17718
# 3       The Avengers Collection  2019-04-24 00:00:00     597       16661
# 4       The Avengers Collection  2019-04-24 00:00:00  135397       15399
# ..                          ...                  ...     ...         ...
# 301  The Incredibles Collection  2018-06-14 00:00:00  181808       10304
# 302  The Incredibles Collection  2018-06-14 00:00:00  330457        3982
# 303  The Incredibles Collection  2018-06-14 00:00:00  351286        7337
# 304  The Incredibles Collection  2018-06-14 00:00:00  109445       11616
# 305  The Incredibles Collection  2018-06-14 00:00:00  321612       12203
#
#      vote_average
# 0             7.4
# 1             7.4
# 2             8.3
# 3             7.8
# 4             6.6
# ..            ...
# 301           7.0
# 302           7.2
# 303           6.5
# 304           7.3
# 305           6.9
#
# [306 rows x 9 columns]

# %%
pd.read_sql("SELECT Movies.id, Movies.title, Votes.vote_average \
             FROM Movies \
             JOIN Votes \
             ON Movies.id=Votes.id",con,index_col="id")
# Out:
#                                                title  vote_average
# id
# 299534                             Avengers: Endgame           8.3
# 19995                                         Avatar           7.4
# 140607                  Star Wars: The Force Awakens           7.4
# 299536                        Avengers: Infinity War           8.3
# 597                                          Titanic           7.8
# 135397                                Jurassic World           6.6
# 420818                                 The Lion King           7.2
# 24428                                   The Avengers           7.7
# 168259                                     Furious 7           7.3
# 99861                        Avengers: Age of Ultron           7.3
# 284054                                 Black Panther           7.4
# 12445   Harry Potter and the Deathly Hallows: Part 2           8.1
# 181808                      Star Wars: The Last Jedi           7.0
# 330457                                     Frozen II           7.2
# 351286                Jurassic World: Fallen Kingdom           6.5
# 109445                                        Frozen           7.3
# 321612                          Beauty and the Beast           6.9
# 260513                                 Incredibles 2           7.5

# %%
pd.read_sql("SELECT Movies.id, Movies.title, Votes.vote_average \
             FROM Movies \
             JOIN Votes \
             ON Movies.id=Votes.id \
             WHERE Votes.vote_average > 8",con,index_col="id")
# Out:
#                                                title  vote_average
# id
# 299534                             Avengers: Endgame           8.3
# 299536                        Avengers: Infinity War           8.3
# 12445   Harry Potter and the Deathly Hallows: Part 2           8.1

# %%
pd.read_sql("SELECT Movies.id, Movies.title, Votes.vote_average \
             FROM Movies \
             JOIN Votes \
             ON Movies.id=Votes.id \
             WHERE Votes.vote_average > 8 \
             ORDER BY Movies.budget ASC",con,index_col="id")
# Out:
#                                                title  vote_average
# id
# 12445   Harry Potter and the Deathly Hallows: Part 2           8.1
# 299536                        Avengers: Infinity War           8.3
# 299534                             Avengers: Endgame           8.3

# %%
con.close()
